# %%
#variable
name="Janani"
trainer="AI/ML Trainer"
Degree="BE ECE"
Exp=3
students= 1.5
clear=True
type(name)
type(Exp)
type(students)
type(clear)
# Out:
# bool

# %%
embstulist=("Kiruthi","Jaya Vignesh","Megala")
type(embstulist)
count=1,2,3,4
type(count)
# Out:
# tuple

# %%
embstulist=["Kiruthi","Jaya Vignesh","Megala"]
type(embstulist)
# Out:
# list

# %%
embstulist={"Kiruthi","Jaya Vignesh","Megala"}
type(embstulist)
# Out:
# set

# %%
embstulist={1:"Kiruthi",2:"Jaya Vignesh",3:"Megala"}
type(embstulist)
# Out:
# dict

# %%
embstulist
# Out:
# {1: 'Kiruthi', 2: 'Jaya Vignesh', 3: 'Megala'}

# %%
for i in range(0,46,3):
  print(i,"hi")
# Out:
# 0 hi
# 2 hi
# 4 hi
# 6 hi
# 8 hi
# 10 hi
# 12 hi
# 14 hi
# 16 hi
# 18 hi
# 20 hi
# 22 hi
# 24 hi
# 26 hi
# 28 hi
# 30 hi
# 32 hi
# 34 hi
# 36 hi
# 38 hi
# 40 hi
# 42 hi
# 44 hi

# %%
count=0
while (count<45):
  print("hi")
  count+=1
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
def add(a,b):
  print(a+b)
add(190,33)
# Out:
# 223

# %%
import numpy as np

# %%
a=np.array([2,3,4,566,8])
a
# Out:
# array([  2,   3,   4, 566,   8])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
import pandas as pd

# %%
b=pd.read_csv("/content/BMW sales data.csv")
b
# Out:
#           Model  Year         Region   Color Fuel_Type Transmission  \
# 0      5 Series  2016           Asia     Red    Petrol       Manual
# 1            i8  2013  North America     Red    Hybrid    Automatic
# 2      5 Series  2022  North America    Blue    Petrol    Automatic
# 3            X3  2024    Middle East    Blue    Petrol    Automatic
# 4      7 Series  2020  South America   Black    Diesel       Manual
# ...         ...   ...            ...     ...       ...          ...
# 49995        i3  2014           Asia     Red    Hybrid       Manual
# 49996        i3  2023    Middle East  Silver  Electric       Manual
# 49997  5 Series  2010    Middle East     Red    Petrol    Automatic
# 49998        i3  2020           Asia   White  Electric    Automatic
# 49999        X1  2020  North America    Blue    Diesel       Manual
#
#        Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# ...

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x=b["Model"]
y=b["Price_USD"]
plt.bar(x,y)
plt.xlabel("Model")
plt.ylabel("Sales_Volume")
plt.show()
